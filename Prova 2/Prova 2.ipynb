# %% [markdown]
# # Prova 2
#
# **Aluno:** Rafael Lúcio Negrão Cordeiro<br/>
# **Matrícula:** 201310323<br/>
# **Disciplina:** CET961 - Engenharia Assistida por Computador
#
#
#
# #### Disclaimer: O software utilizado na simulaçao apresenta licença educacional da Universidade Estadual de Santa Cruz. O presente estudo de caso tem por finalidade o entendimento desta ferramenta, como forma de avaliaçao da disciplina `CET961 - Engenharia Assistida por Computador` do `Departamento de Ciencias Exatas e Tecnológicas`. O autor deste arquivo nao pretende, com o presente estudo de caso, reivindicar direitos autorais ou de propriedade sobre o software utilizado para obter os resultados da simulaçao.

# %% [markdown]
# #### De acordo com o exposto no enunciado, foi feito um modelo que representasse a transmissao de cargas da figura do enunciado:
# ![image.png](attachment:f6baa847-9fcc-4a43-8483-0bf87647ef07.png)

# %% [markdown]
# #### Com base no desenho técnico, também presente no enunciado, foi modelado um reboque e um pino, como a seguir:
#
# ![image.png](attachment:9fdc3b98-c330-4dad-9a17-9986059dbe59.png)
# ![image.png](attachment:e247bdc2-1f27-4bd6-99c9-afc6db2b34bb.png)

# %% [markdown]
# #### Onde a montagem ficou da seguinte forma:
#
# ![image.png](attachment:f730e4dc-d5b7-4b02-80ea-994784f759fb.png)

# %% [markdown]
# #### Embora na ilustraçao da `figura 2`, no enunciado, mostre um pino com parte superior esférica, esta parte esférica nao influencia na transmissao da carga para o `Reboque`.
#
# #### A transmissao das tensoes especificadas se dao através do contato do pino com o reboque. O pino modelado, portanto, apresenta apenas a similaridade necessária na geometria que entra em contato com o reboque.
#
# #### O pino tem altura tal que a linha média da face que recebe a solicitaçao de `4900N` esteja na altura de `40mm`. A face superior do pino recebe, de forma distribuída, a solicitaçao de `990N`.

# %% [markdown]
# #### As forças foram definidas da seguinte maneira:
#
# ![image.png](attachment:e38ec6de-47b0-4b60-9fef-823fce8309c5.png)
# ![image.png](attachment:dd209232-7af4-4618-b0e7-90f877594d63.png)

# %% [markdown]
# #### As fixaçoes foram definidas com duas restriçoes. Uma restriçao foi aplicada na parede dos furos que suportam o `Reboque`. A outra restriçao foi aplicada na face perpenticular a parede dos furos. Foram utilizados os seguintes recursos, respectivamente:
#
#  - Roller/Slider;
#  - Fixed Hinge.
#
# A fixaçao `Roller/Slider` impede movimento, da face espeficicada, na direçao do eixo `Axis2`. Essa restriçao nao impede que o modelo se movimente em qualquer direçao paralela a própria face.
#
# A fixaçao `Fixed Hinge` impede movimento em quaisquer das direçoes radiais das paredee dos furos selecionados, mas permite que o modelo se movimente em quaisquer dos dois sentidos do eixo `Axis2`.
#
# Essas duas fixaçoes aplicadas em conjunto permitem obter um resultado mais coerente do que se fosse aplicado uma restriçao de fixaçao geométrica, visto que esta restriçao implica que, independente das cargas impostas no modelo, o componente geométrico que estiver com uma fixaçao geométrica nunca se deformará.
#
# Com as duas fixaçoes utilizadas poderíamos ver, por exemplo, as paredes dos furos se deformando.

# %% [markdown]
# #### As fixaçoes foram definidas como a seguir:
#
# ![image.png](attachment:97e71c25-f779-4385-a606-91c6caed46fe.png)
# ![image.png](attachment:66a55f52-feb0-4c1d-b152-86b378ce374f.png)

# %% [markdown]
# #### A malha foi definida usando as opçoes mais finas permitidas pelo software:
#
# ![image.png](attachment:8a2d4798-99ba-4b36-8565-b21fb611bb75.png)
#
# Interessante observar que o software organizou a geometria a ser simulada, considerando apenas o plano médio de toda a geometria do `Reboque`

# %% [markdown]
# #### O resultado da simulaçao se deu, como a seguir:
#
# ![image.png](attachment:26d65900-162a-41cd-905f-bd4e2e5c5b35.png)
# ![image.png](attachment:0a1a5a56-2a2b-4273-a4e1-aa901b695bca.png)

# %% [markdown]
# #### Como resultado, a simulaçao apresenta uma aparente grande deformaçao em funçao da magnificaçao dos deslocamentos, para se tornarem visíveis. Apesar disso, os valores máximos de estresse estao abaixo do limite de escoamento do aço AISI 1045 Trefilado, embora o conjunto nao apresente um coeficiente de segurança razoável para utilizaçao em um reboque.
