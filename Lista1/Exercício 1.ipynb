# %% [markdown]
# # Exercício 1
#
# **Aluno:** Rafael Lúcio Negrão Cordeiro<br/>
# **Matrícula:** 201310323<br/>
# **Disciplina:** CET961 - Engenharia Assistida por Computador

# %%
k1 = 400 # N / mm
k2 = 500 # N / mm
k3 = 500 # N / mm
k4 = 300 # N / mm

f4 = 1000 # N

u1 = 0 # Unidade de deslocamento

# %% [markdown]
# #### Compondo o sistema na notaçao matricial $[K^{(g)}]\{U^{(g)}\} = \{F^{(g)}\}$, temos:
#
# $$
# \overbrace{
#     \begin{bmatrix}
#         k_1+k_3 & -k_1 & -k_3 & 0\\
#         -k_1 & k_1+k_2 & -k_2 & 0\\
#         -k_3 & -k_2 & k_2+k_3+k_4 & -k_4\\
#         0 & 0 & -k_4 & k_4\\
#     \end{bmatrix}
# }^{[K^{(g)}]}
# \overbrace{
#     \begin{Bmatrix}
#         u_1\\
#         u_2\\
#         u_3\\
#         u_4\\
#     \end{Bmatrix}
# }^{\{U^{(g)}\}}
# =
# \overbrace{
#     \begin{Bmatrix}
#         f_1\\
#         f_2\\
#         f_3\\
#         f_4\\
#     \end{Bmatrix}
# }^{\{F^{(g)}\}}
# $$
# Onde, substituindo, temos:
# $$
# \begin{bmatrix}
#     400+500 & -400 & -500 & 0\\
#     -400 & 400+500 & -500 & 0\\
#     -500 & -500 & 500+500+300 & -300\\
#     0 & 0 & -300 & 300\\
# \end{bmatrix}
# \begin{Bmatrix}
#     0\\
#     u_2\\
#     u_3\\
#     u_4\\
# \end{Bmatrix}
# =
# \begin{Bmatrix}
#     R_1\\
#     R_2\\
#     R_3\\
#     1000\\
# \end{Bmatrix}
# $$

# %% [markdown]
# #### Ao executar as multiplicações das matrizes, temos:
# $$
# \begin{equation}
#     \begin{cases}
#         -400u_2 - 500u_3 = R_1\\
#         900u_2 - 500u_3 = R_2\\
#         -500u_2 + 1300u_3 -300u_4 = R_3\\
#         -300u_3 + 300u_4= 1000\\
#     \end{cases}
# \end{equation}
# $$
#
# Se isolarmos todas as variáveis para o lado esquerdo da equaçao, teremos: $ \begin{equation}
#     \begin{cases}
#         400u_2 - 500u_3 + 0u_4 - R_1 + 0R_2 + 0R_3 = 0\\
#         900u_2 - 500u_3 + 0u_4 + 0R_1 - R_2 + 0R_3 = 0\\
#         500u_2 + 1300u_3 - 300u_4 + 0R_1 + 0R_2 - R_3 = 0\\
#         0u_2 - 300u_3 + 300u_4 + 0R_1 + 0R_2 + 0R_3 = 0\\
#     \end{cases}
# \end{equation} $
#
# Da algebra linear, verifica-se que é impossível resolver um sistema de 4 equaçoes com 5 variáveis. Ainda assim, vamos tentar montar com uma matriz de seus coeficientes:
#
# $$
# \begin{bmatrix}
#     -400 & -500 & 0 & -1 & 0 & 0\\
#     -900 & -500 & 0 & 0 & -1 & 0\\
#     -500 & 1300 & -300 & 0 & 0 & -1\\
#     0 & -300 & 300 & 0 & 0 & 0\\
# \end{bmatrix}
# \begin{bmatrix}
#     u_2\\
#     u_3\\
#     R_1\\
#     R_2\\
#     R_3\\
# \end{bmatrix}
# =
# \begin{bmatrix}
#     1\\
#     1\\
#     1\\
#     1\\
#     1000\\
# \end{bmatrix}
# $$
